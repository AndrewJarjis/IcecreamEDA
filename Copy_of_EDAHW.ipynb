# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewJarjis/IcecreamEDA/blob/main/Copy_of_EDAHW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


data = [38, 29, 48, 29, 32, 37, 18, 38, 14, 13, 30, 26, 48, 15, 35, 28, 18, 31, 24, 33, 25, 13, 32, 37, 39, 41, 38, 40, 18, 35, 18, 12, 27, 43, 22, 38, 23, 37, 27, 12, 12, 37, 15, 30, 28, 24, 12, 34, 17, 32, 16, 14, 18, 40, 23, 20, 19, 47, 44, 11, 35, 16, 15, 26, 15, 35, 17, 30, 19, 38, 34, 28, 29, 25, 21, 49, 43, 42, 24, 20, 10, 23, 10, 28, 24, 24, 15, 46, 41, 14, 17, 16, 39, 32, 36, 18, 24, 40, 45, 27, 39, 21, 19, 10, 12, 10, 39, 19, 45, 19, 46, 14, 15, 12, 36, 10, 48, 26, 49, 33, 39, 34, 35, 28, 38, 35, 14, 31, 31, 35, 46, 39, 38, 16, 47, 10, 33, 22, 22, 49, 46, 46, 43, 19, 49, 21, 34, 45, 26, 43, 18, 42, 12, 41, 21, 17, 40, 23, 25, 44, 49, 29, 28, 38, 14, 22, 11, 24, 14, 22, 39, 20, 29, 24, 18, 37, 30, 34, 45, 21, 43, 22, 37, 17, 26, 35, 43, 38, 47, 30, 25, 25, 48, 15, 40, 17, 41, 14, 22, 22, 35, 32, 12, 17, 40, 19, 33, 44, 16, 45, 20, 20, 42, 21, 34, 26, 23, 16, 39, 45, 29, 35, 23, 13, 49, 45, 15, 47, 10, 39, 46, 19, 42, 24, 27, 27, 43, 36, 12, 46, 11, 15, 32, 17, 45, 26, 11, 37, 37, 10, 47, 12, 45, 11, 19, 20, 45, 38, 33, 15, 42, 47, 10, 29, 37, 43, 27, 39, 14, 19, 23, 26, 21, 29, 11, 26, 23, 24, 38, 17, 13, 41, 43, 12, 32, 48, 14, 29, 28, 18, 34, 43, 13, 11, 17, 42, 12, 41, 11, 38, 36, 32, 24, 44, 41, 20, 30, 28, 39, 25, 48, 44, 35, 26, 12, 39, 23, 30, 27, 36, 49, 30, 28, 18, 24, 36, 28, 17, 22, 12, 33, 14, 25, 42, 32, 30, 33, 19, 12, 48, 37, 35, 32, 14, 12, 12, 26, 16, 17, 48, 49, 27, 35, 45, 37, 23, 12, 21, 28, 16, 44, 46, 39, 37, 43]


bin_width = 5


plt.hist(data, bins=range(min(data), max(data) + bin_width, bin_width))


plt.xlabel('Value')
plt.ylabel('Frequency')


plt.show()

# %%
temperature = [57.56, 61.52, 53.42, 59.36, 65.3, 71.78, 66.92, 77.18, 74.12, 64.58]


sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421]


plt.scatter(temperature, sales)


plt.xlabel('Temperature (°F)')
plt.ylabel('Sales ($)')

plt.title('Frozen Yogurt Sales vs Temperature')

plt.show()

# %%
months = list(range(1, 13))
sales = [2630, 1200, 5100, 6100, 2100, 1200, 18330, 183300,
         2140, 1340, 4550, 9550, 3550, 1340, 22470, 224700,
         3400, 1130, 5870, 8870, 1870, 1130, 22270, 222700,
         3600, 1740, 4560, 7760, 1560, 1740, 20960, 209600,
         2760, 1555, 4890, 7490, 1890, 1555, 20140, 201400,
         2980, 1120, 4780, 8980, 1780, 1120, 29550, 295500,
         3700, 1400, 5860, 9960, 2860, 1400, 36140, 361400,
         3540, 1780, 6100, 8100, 2100, 1780, 23400, 234000,
         1990, 1890, 8300, 10300, 2300, 1890, 26670, 266700,
         2340, 2100, 7300, 13300, 2400, 2100, 41280, 412800,
         2900, 1760, 7400, 14400, 1800, 1760, 30020, 300200]


total_sales = [sum(sales[i:i+8]) for i in range(0, len(sales), 8)]

months = months[:len(total_sales)]


plt.plot(months, total_sales, marker='o')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Total Sales of Ice Cream over Time')
plt.xticks(months)
plt.grid(True)


plt.show()

# %%
months = list(range(1, 13))
sales = [2630, 1200, 5100, 6100, 2100, 1200, 18330, 183300,
         2140, 1340, 4550, 9550, 3550, 1340, 22470, 224700,
         3400, 1130, 5870, 8870, 1870, 1130, 22270, 222700,
         3600, 1740, 4560, 7760, 1560, 1740, 20960, 209600,
         2760, 1555, 4890, 7490, 1890, 1555, 20140, 201400,
         2980, 1120, 4780, 8980, 1780, 1120, 29550, 295500,
         3700, 1400, 5860, 9960, 2860, 1400, 36140, 361400,
         3540, 1780, 6100, 8100, 2100, 1780, 23400, 234000,
         1990, 1890, 8300, 10300, 2300, 1890, 26670, 266700,
         2340, 2100, 7300, 13300, 2400, 2100, 41280, 412800,
         2900, 1760, 7400, 14400, 1800, 1760, 30020, 300200]

total_units_sold = [sum(sales[i:i+8]) for i in range(0, len(sales), 8)]

months = months[:len(total_units_sold)]


plt.bar(months, total_units_sold)
plt.xlabel('Month')
plt.ylabel('Total Units Sold')
plt.title('Total Units Sold per Month')
plt.xticks(months)
plt.grid(True)

plt.show()
